# %%
import os
import shutil

# %%
os.chdir('U:\LUCADI\Images')

# %%
items = []
for currentpath, folders, files in os.walk('U:\LUCADI\Images'):
    for folder in folders:
        items.append(os.path.join(currentpath, folder))

#items is a list of folders
for folder in items:
    cmd_to_run = "dcm2niix -o U:\\LUCADI\\NIFTI -z y -f %%f -d 2 -b n -i y \"%s\"" % folder
    print("Command to run: {}".format(cmd_to_run))
    os.system(cmd_to_run)
# Out:
# Command to run: dcm2niix -o U:\LUCADI\NIFTI -z y -f %f -d 2 -b n -i y "U:\LUCADI\Images\LUC_0001_Scan 1"
# Command to run: dcm2niix -o U:\LUCADI\NIFTI -z y -f %f -d 2 -b n -i y "U:\LUCADI\Images\LUC_0001_Scan 2"
# Command to run: dcm2niix -o U:\LUCADI\NIFTI -z y -f %f -d 2 -b n -i y "U:\LUCADI\Images\LUC_0002_Scan 1"
# Command to run: dcm2niix -o U:\LUCADI\NIFTI -z y -f %f -d 2 -b n -i y "U:\LUCADI\Images\LUC_0002_Scan 2"
# Command to run: dcm2niix -o U:\LUCADI\NIFTI -z y -f %f -d 2 -b n -i y "U:\LUCADI\Images\LUC_0002_Scan 3"
# Command to run: dcm2niix -o U:\LUCADI\NIFTI -z y -f %f -d 2 -b n -i y "U:\LUCADI\Images\LUC_0003_Scan 1"
# Command to run: dcm2niix -o U:\LUCADI\NIFTI -z y -f %f -d 2 -b n -i y "U:\LUCADI\Images\LUC_0003_Scan 2"
# Command to run: dcm2niix -o U:\LUCADI\NIFTI -z y -f %f -d 2 -b n -i y "U:\LUCADI\Images\LUC_0003_Scan 3"
# Command to run: dcm2niix -o U:\LUCADI\NIFTI -z y -f %f -d 2 -b n -i y "U:\LUCADI\Images\LUC_0004_Scan 1"
# ...
